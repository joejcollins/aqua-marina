# %% [markdown]
# # Thresholding the Maize Root

# %%
import imageio.v3 as iio
from aqua_marina import file_finder_service

my_file_finder = file_finder_service.FileFinderService()


maize_roots = iio.imread(uri="../data/maize-root-cluster.jpg")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 2
#       1 import imageio.v3 as iio
# ----> 2 from aqua_marina import file_finder_service
#       4 my_file_finder = file_finder_service.FileFinderService()
#       7 maize_roots = iio.imread(uri="../data/maize-root-cluster.jpg")
#
# ModuleNotFoundError: No module named 'aqua_marina'
