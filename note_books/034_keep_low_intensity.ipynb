# %%
# Keep Low Intensity Regions

# %%
import imageio.v3 as iio
from aqua_marina import file_finder_service, image_display

sudoku_path = file_finder_service.find_training_image("sudoku.png")
sudoku_image = iio.imread(uri=sudoku_path)
image_display.show(sudoku_image, title="Sudoku")

# %%
sudoku_image[sudoku_image < 192] = 0
image_display.show(sudoku_image, title="Sudoku")
